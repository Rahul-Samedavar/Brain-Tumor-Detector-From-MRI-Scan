# %%
from tensorflow.keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt

# %%
from GradCam import *

# %%
model = load_model(r'Models\Xception\model_epoch_16.keras')

# %%
image_path = r"Dataset\Testing\glioma\Te-gl_0010.jpg"

# %%
layer_name = "block14_sepconv2_act"

# %%
grad_cam_visualize(model, image_path, layer_name)

# %%
grad_cam_plus_plus_visualize(model, image_path, layer_name)

# %%
from util import *

# %%
predict(image_path, model)
# Out:
# 0

# %%
classify(image_path, model)
# Out:
# 'glioma'
